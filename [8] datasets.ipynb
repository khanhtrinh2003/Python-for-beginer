# %%
import requests
from function.alphas_function import*
import pandas as pd

# %%
# datasets=['fundamental28']
for i in datasets:
  url = f"https://api.worldquantbrain.com/references/{i}"

  payload={}
  headers = {
    'authority': 'api.worldquantbrain.com',
    'accept': 'application/json;version=2.0',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': '_ga=GA1.1.83536437.1682770993; _ga_KRGKFCSV1C=GS1.1.1683941024.4.1.1683941060.0.0.0; t=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiJmMUF4bUNIaGxQWlVvUWxBbUlZbmJLOWxSVFlqOFpMMSIsImV4cCI6MTY4NDE0MzI4N30.L89Ft81KEEtmxtsLmhyPKzAXWcGWhdAJ5px0OaGbDC4; _ga_9RN6WVT1K1=GS1.1.1684128279.82.1.1684128890.58.0.0; _ga_FXKNEPLB1N=GS1.1.1684128279.82.1.1684128890.0.0.0',
    'origin': 'https://platform.worldquantbrain.com',
    'referer': 'https://platform.worldquantbrain.com/',
    'sec-ch-ua': '"Google Chrome";v="113", "Chromium";v="113", "Not-A.Brand";v="24"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36'
  }

  response = requests.request("GET", url, headers=headers, data=payload)
  table_MN = pd.read_html(response.text)
  df = table_MN[0]
  df1=pd.DataFrame(df[['Field','Delay','Type']].values,columns=['Field','Delay','Type'])
  df1['dataset']=i
  save(df1,'datasets.csv')

# %%
df=pd.read_csv('datasets.csv')

# %%
df
# Out:
#                          Field  Delay    Type        dataset
# 0     fnd28_18100_value_18100q      1  matrix  fundamental28
# 1          fnd28_2_value_05002      1  matrix  fundamental28
# 2          fnd28_2_value_05003      1  matrix  fundamental28
# 3          fnd28_2_value_08004      1  matrix  fundamental28
# 4     fnd28_anaut_value_08136a      1  matrix  fundamental28
# ...                        ...    ...     ...            ...
# 3662    fnd28_wsu_value_04829a      1  matrix  fundamental28
# 3663    fnd28_wsu_value_04830a      1  matrix  fundamental28
# 3664    fnd28_wsu_value_04831a      1  matrix  fundamental28
# 3665    fnd28_wsu_value_04840a      1  matrix  fundamental28
# 3666    fnd28_wsu_value_04851a      1  matrix  fundamental28
#
# [3667 rows x 4 columns]
